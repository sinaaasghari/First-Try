# %%
import numpy as np
import pandas as pd

# %%
a='R'
b='98'
tr98=[]
for file in pd.ExcelFile('data/'+a+b+'.xlsx').sheet_names:
    tr98.append(pd.read_excel('data/'+a+b+'.xlsx',sheet_name=file))

# %%
dftr98=tr98[0]
#dftr98=dftr98.merge(tr98[1],on='Address',how='left')
dftr98=dftr98.merge(tr98[2],on='Address',how='left')
dftr98=dftr98.merge(tr98[3].groupby('Address').agg({'value':'sum'}).rename(columns={'value':'Cost1'}),on='Address',how='left')
dftr98=dftr98.merge(tr98[4].groupby('Address').agg({'value':'sum'}).rename(columns={'value':'Cost2'}),on='Address',how='left')
dftr98=dftr98.merge(tr98[5].groupby('Address').agg({'value':'sum'}).rename(columns={'value':'Cost3'}),on='Address',how='left')
dftr98=dftr98.merge(tr98[6].groupby('Address').agg({'value':'sum'}).rename(columns={'value':'Cost4'}),on='Address',how='left')
dftr98=dftr98.merge(tr98[7].groupby('Address').agg({'value':'sum'}).rename(columns={'value':'Cost5'}),on='Address',how='left')
dftr98=dftr98.merge(tr98[8].groupby('Address').agg({'value':'sum'}).rename(columns={'value':'Cost6'}),on='Address',how='left')
dftr98=dftr98.merge(tr98[9].groupby('Address').agg({'value':'sum'}).rename(columns={'value':'Cost7'}),on='Address',how='left')
dftr98=dftr98.merge(tr98[10].groupby('Address').agg({'value':'sum'}).rename(columns={'value':'Cost8'}),on='Address',how='left')
dftr98=dftr98.merge(tr98[11].groupby('Address').agg({'value':'sum'}).rename(columns={'value':'Cost9'}),on='Address',how='left')
dftr98=dftr98.merge(tr98[13].groupby('Address').agg({'value':'sum'}).rename(columns={'value':'Cost11'}),on='Address',how='left')
dftr98=dftr98.merge(tr98[14].groupby('Address').agg({'value':'sum'}).rename(columns={'value':'Cost12'}),on='Address',how='left')
dftr98=dftr98.merge(tr98[15].groupby('Address').agg({'value':'sum'}).rename(columns={'value':'Cost13'}),on='Address',how='left')
dftr98=dftr98.merge(tr98[16].groupby('Address').agg({'value':'sum'}).rename(columns={'value':'Cost14'}),on='Address',how='left')
#house  price 1
dftr98=dftr98.merge(tr98[6][tr98[6]['code'].apply(lambda x:x//1000==41)].groupby('Address').agg({'value':'sum'}).rename(columns={'value':'HousePrice1'}),on='Address',how='left')
#house price 2
dftr98=dftr98.merge(tr98[6][tr98[6]['code'].apply(lambda x:x//1000==42)].groupby('Address').agg({'value':'sum'}).rename(columns={'value':'HousePrice2'}),on='Address',how='left')
# fuel
dftr98=dftr98.merge(tr98[6][tr98[6]['code'].apply(lambda x:x//1000==45)].groupby('Address').agg({'value':'sum'}).rename(columns={'value':'Fuel'}),on='Address',how='left')
#car fuel
dftr98=dftr98.merge(tr98[9][tr98[9]['code'].apply(lambda x:x//100==722)].groupby('Address').agg({'value':'sum'}).rename(columns={'value':'Car_Fuel'}),on='Address',how='left')
#benzin
dftr98=dftr98.merge(tr98[9][tr98[9]['code'].apply(lambda x:x==72211)].groupby('Address').agg({'value':'sum'}).rename(columns={'value':'Benzin'}),on='Address',how='left')


dftr98
# Out:
#            Address  MahMorajeh  Fasl      weight  khanevartype  Takmil  \
# 0      20001383908           5     2  171.199524             1       1
# 1      20001383911           5     2  171.199524             1       2
# 2      20001383915           5     2  171.199524             1       2
# 3      20001383916           5     2  171.199524             1       1
# 4      20001383920           5     2  171.199524             1       2
# ...            ...         ...   ...         ...           ...     ...
# 18425  23006709717           9     3   84.791023             1       2
# 18426  23006709720           9     3   84.791023             1       2
# 18427  23006709723           9     3   84.791023             1       1
# 18428  23006709807           1     4  254.373068             1       1
# 18429  23006709818           1     4  254.373068             1       2
#
#        TakmilDescA  TakmilDescB TakmilDescC  Jaygozin  ...     Cost9  \
# ...

# %%
dftr98.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64296 entries, 0 to 64295
# Data columns (total 88 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Address              64296 non-null  int64
#  1   MahMorajeh           64296 non-null  int64
#  2   Fasl                 64296 non-null  int64
#  3   weight               64296 non-null  float64
#  4   khanevartype         64296 non-null  int64
#  5   Takmil               64296 non-null  int64
#  6   TakmilDescA          0 non-null      float64
#  7   TakmilDescB          11722 non-null  float64
#  8   TakmilDescC          94 non-null     object
#  9   Jaygozin             11722 non-null  float64
#  10  JaygozinDescA        0 non-null      float64
#  11  JaygozinDescB        0 non-null      float64
#  12  JaygozinDescC        0 non-null      float64
#  13  BlkAbdJaygozin       11722 non-null  float64
#  14  RadifJaygozin        11722 non-null  float64
# ...

# %%
def read_data(a,b):
    temp=[]
    for file in pd.ExcelFile('data/'+a+b+'.xlsx').sheet_names:
        temp.append(pd.read_excel('data/'+a+b+'.xlsx',sheet_name=file))
    df=temp[0]
    #df=df.merge(temp[1],on='Address',how='left')
    df=df.merge(temp[2],on='Address',how='left')
    df=df.merge(temp[3].groupby('Address').agg({'value':'sum'}).rename(columns={'value':'Cost1'}),on='Address',how='left')
    df=df.merge(temp[4].groupby('Address').agg({'value':'sum'}).rename(columns={'value':'Cost2'}),on='Address',how='left')
    df=df.merge(temp[5].groupby('Address').agg({'value':'sum'}).rename(columns={'value':'Cost3'}),on='Address',how='left')
    df=df.merge(temp[6].groupby('Address').agg({'value':'sum'}).rename(columns={'value':'Cost4'}),on='Address',how='left')
    df=df.merge(temp[7].groupby('Address').agg({'value':'sum'}).rename(columns={'value':'Cost5'}),on='Address',how='left')
    df=df.merge(temp[8].groupby('Address').agg({'value':'sum'}).rename(columns={'value':'Cost6'}),on='Address',how='left')
    df=df.merge(temp[9].groupby('Address').agg({'value':'sum'}).rename(columns={'value':'Cost7'}),on='Address',how='left')
    df=df.merge(temp[10].groupby('Address').agg({'value':'sum'}).rename(columns={'value':'Cost8'}),on='Address',how='left')
    df=df.merge(temp[11].groupby('Address').agg({'value':'sum'}).rename(columns={'value':'Cost9'}),on='Address',how='left')
    df=df.merge(temp[13].groupby('Address').agg({'value':'sum'}).rename(columns={'value':'Cost11'}),on='Address',how='left')
    df=df.merge(temp[14].groupby('Address').agg({'value':'sum'}).rename(columns={'value':'Cost12'}),on='Address',how='left')
    df=df.merge(temp[15].groupby('Address').agg({'value':'sum'}).rename(columns={'value':'Cost13'}),on='Address',how='left')
    df=df.merge(temp[16].groupby('Address').agg({'value':'sum'}).rename(columns={'value':'Cost14'}),on='Address',how='left')
    #house  price 1
    df=df.merge(temp[6][temp[6]['code'].apply(lambda x:x//1000==41)].groupby('Address').agg({'value':'sum'}).rename(columns={'value':'HousePrice1'}),on='Address',how='left')
    #house price 2
    df=df.merge(temp[6][temp[6]['code'].apply(lambda x:x//1000==42)].groupby('Address').agg({'value':'sum'}).rename(columns={'value':'HousePrice2'}),on='Address',how='left')
    # fuel
    df=df.merge(temp[6][temp[6]['code'].apply(lambda x:x//1000==45)].groupby('Address').agg({'value':'sum'}).rename(columns={'value':'Fuel'}),on='Address',how='left')
    #car fuel
    df=df.merge(temp[9][temp[9]['code'].apply(lambda x:x//100==722)].groupby('Address').agg({'value':'sum'}).rename(columns={'value':'Car_Fuel'}),on='Address',how='left')
    #benzin
    df=df.merge(temp[9][temp[9]['code'].apply(lambda x:x==72211)].groupby('Address').agg({'value':'sum'}).rename(columns={'value':'Benzin'}),on='Address',how='left')
    return df

# %%
df=[]
for a in ['R','U']:
    temp=[]
    for b in ['98','99','1400','1401']:
        print(a,b)
        x=read_data(a,b)
        x['year']=b
        temp.append(x)
    x=pd.concat(temp)
    x['state']=a
    df.append(x)
df=pd.concat(df)
# Out:
# R 98
# R 99
# R 1400
# R 1401
# U 98
# U 99
# U 1400
# U 1401

# %%
df
# Out:
#            Address  MahMorajeh  Fasl       weight  khanevartype  Takmil  \
# 0      20001383908         5.0     2   171.199524             1       1
# 1      20001383908         5.0     2   171.199524             1       1
# 2      20001383908         5.0     2   171.199524             1       1
# 3      20001383908         5.0     2   171.199524             1       1
# 4      20001383911         5.0     2   171.199524             1       2
# ...            ...         ...   ...          ...           ...     ...
# 64730  13006383838         NaN     2  2154.650617             1       2
# 64731  13006383838         NaN     2  2154.650617             1       2
# 64732  13006383841         NaN     2  2154.650617             1       1
# 64733  13006383841         NaN     2  2154.650617             1       1
# 64734  13006383841         NaN     2  2154.650617             1       1
#
#       TakmilDescA TakmilDescB TakmilDescC Jaygozin  ... Cost14 HousePrice1  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 516888 entries, 0 to 64734
# Data columns (total 92 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Address              516888 non-null  int64
#  1   MahMorajeh           261496 non-null  float64
#  2   Fasl                 516888 non-null  int64
#  3   weight               516888 non-null  float64
#  4   khanevartype         516888 non-null  int64
#  5   Takmil               516888 non-null  int64
#  6   TakmilDescA          126478 non-null  object
#  7   TakmilDescB          209770 non-null  object
#  8   TakmilDescC          141128 non-null  object
#  9   Jaygozin             209770 non-null  object
#  10  JaygozinDescA        126478 non-null  object
#  11  JaygozinDescB        126478 non-null  object
#  12  JaygozinDescC        0 non-null       float64
#  13  BlkAbdJaygozin       111377 non-null  float64
#  14  RadifJaygozin        111377 non-null  float64
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

np.random.seed(42)
incomes = np.random.rand(100) * 100000  
spent = np.random.rand(100) * 50000     

# incomes and expenditures must be handled in preprocessing part

#######################
# clustering part one #
#######################

data = np.vstack((incomes, spent)).T

K = 10
kmeans = KMeans(n_clusters=K, random_state=42)
kmeans.fit(data)

labels = kmeans.labels_
centroids = kmeans.cluster_centers_

plt.figure(figsize=(10, 6))
plt.scatter(data[:, 0], data[:, 1], c=labels, s=50, cmap='viridis')
plt.scatter(centroids[:, 0], centroids[:, 1], c='red', s=200, alpha=0.75, marker='X')
plt.xlabel('Income')
plt.ylabel('Spent')
plt.title('K-means Clustering of Income and Spent')
plt.show()

#######################
# clustering part two #
#######################

wcss = []

for k in range(1, 21):
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(data)
    wcss.append(kmeans.inertia_)

plt.figure(figsize=(10, 6))
plt.plot(range(1, 21), wcss, marker='o')
plt.xlabel('Number of clusters (K)')
plt.ylabel('Within-Cluster Sum of Square (WCSS)')
plt.title('Elbow Method For Optimal K')
plt.show()

print("Elbow depends on the data but with my random data that point is k = 4")
# Out:
# /home/donya/miniconda3/envs/quera/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# Exception ignored on calling ctypes callback function: <function _ThreadpoolInfo._find_modules_with_dl_iterate_phdr.<locals>.match_module_callback at 0x7827607a4700>
# Traceback (most recent call last):
#   File "/home/donya/miniconda3/envs/quera/lib/python3.10/site-packages/threadpoolctl.py", line 400, in match_module_callback
#     self._make_module_from_path(filepath)
#   File "/home/donya/miniconda3/envs/quera/lib/python3.10/site-packages/threadpoolctl.py", line 515, in _make_module_from_path
#     module = module_class(filepath, prefix, user_api, internal_api)
#   File "/home/donya/miniconda3/envs/quera/lib/python3.10/site-packages/threadpoolctl.py", line 606, in __init__
# ...
